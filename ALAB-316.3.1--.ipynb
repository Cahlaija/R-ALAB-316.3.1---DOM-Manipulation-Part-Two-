# %%
const mainEl = documemnt.querySlector('main');

//set background color of main
mainEl.style.beackgroundColor = 'var(--main-bg)';

//add flex classes to main
mainEl.classList.add('flex-ctr');

//set intial content
mainEl.innerHTML = '<h1>DOM Manipulation</h1>';

//top menu element
const topMenuEl = document.getElementById('top-menu');

//set height of top menu
topMenuEl.style.height = '100%';

//set background color of top menu
topMenuEl.style.backgroundColor = 'var(--top-menu-bg)';

//add flex-around class
topMenuEl.classList.add('flex-around');

/*--Menu Data--*/
var menuLinks = [
{text:'about',href: '/about'},
{
text:'catalog',
href: '#',
subLinks: [
{text:'all',href:'/catalog/all'},
{text:'top selling', href: 'catalog/top'},
{text:'search', href: '/catalog/search'},
],
},
]

{
text:"orders",
href:'#',
subLinks:[
    {text: 'new', href: '/order/new'},
    {text: 'pending', href: '/orders/pending'},
    {text: 'history', href: '/orders/history'},

],
},
{
text: 'account',
href: '#',
subLinks: [

    
]


}
